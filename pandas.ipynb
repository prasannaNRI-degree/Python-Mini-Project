# %% [markdown]
# <a href="https://colab.research.google.com/github/prasannaNRI-degree/Python-Mini-Project/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
import pandas as pd
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [58,
#   65,
#   20,
#   78,
#   0,
#   19,
#   63,
#   5,
#   87,
#   25,
#   10,
#   67,
#   62,
#   87,
#   66,
#   63,
#   14,
#   44,
#   22,
#   89,
#   67,
#   0,
#   17,
#   7,
#   16,
#   100,
#   98,
#   18,
#   67,
#   52,
#   29,
#   70,
#   87,
#   31,
#   54,
#   42,
#   13,
#   11,
#   39,
#   18,
#   62,
#   64,
#   52,
#   19,
#   90,
#   47,
#   59,
#   48,
#   9,
#   83,
#   73,
#   9,
#   91,
#   82,
#   42,
#   30,
#   46,
#   41,
#   52,
#   28,
#   7,
#   42,
#   67,
#   61,
#   95,
#   7,
#   27,
#   4,
#   21,
#   93,
#   34,
#   49,
#   91,
#   44,
#   61,
#   49,
#   81,
#   44,
#   57,
#   0,
#   21,
#   20,
#   77,
#   35,
#   21,
#   34,
#   66,
#   40,
#   99,
#   30,
#   45,
#   98,
#   9,
#   5,
#   32,
#   66,
#   62,
#   57,
#   60,
#   85],
#  'Height': [88,
#   8,
#   55,
#   86,
#   46,
#   7,
#   56,
#   82,
#   97,
#   2,
#   27,
#   64,
#   28,
#   80,
#   94,
#   58,
#   36,
#   50,
#   58,
#   50,
#   9,
#   62,
#   84,
#   65,
#   14,
#   97,
#   71,
#   9,
#   16,
#   96,
#   27,
#   53,
#   74,
#   72,
#   50,
#   44,
#   85,
#   99,
#   44,
#   27,
#   62,
#   49,
#   60,
#   57,
#   78,
#   63,
#   97,
#   72,
#   44,
#   74,
#   5,
#   57,
#   19,
#   90,
#   87,
#   59,
#   33,
#   86,
#   59,
#   36,
#   58,
#   1,
#   3,
#   48,
#   66,
#   1,
#   96,
#   86,
#   99,
#   95,
#   80,
#   11,
#   27,
#   97,
#   22,
#   27,
#   46,
#   60,
#   65,
#   39,
#   52,
#   51,
#   13,
#   94,
#   23,
#   19,
#   0,
#   84,
#   17,
#   76,
#   65,
#   3,
#   9,
#   67,
#   57,
#   89,
#   44,
#   1,
#   78,
#   65],
#  'Weight': [77,
#   87,
#   74,
#   75,
#   66,
#   34,
#   52,
#   47,
#   61,
#   21,
#   61,
#   16,
#   82,
#   25,
#   48,
#   86,
#   8,
#   42,
#   62,
#   28,
#   96,
#   47,
#   25,
#   61,
#   20,
#   9,
#   17,
#   27,
#   67,
#   0,
#   50,
#   15,
#   5,
#   90,
#   80,
#   5,
#   94,
#   43,
#   90,
#   79,
#   74,
#   74,
#   43,
#   90,
#   40,
#   73,
#   51,
#   9,
#   25,
#   26,
#   83,
#   33,
#   30,
#   46,
#   5,
#   99,
#   55,
#   88,
#   23,
#   1,
#   42,
#   62,
#   65,
#   41,
#   57,
#   36,
#   15,
#   83,
#   16,
#   35,
#   95,
#   45,
#   85,
#   44,
#   94,
#   70,
#   31,
#   35,
#   58,
#   16,
#   19,
#   8,
#   63,
#   97,
#   86,
#   71,
#   68,
#   31,
#   3,
#   98,
#   86,
#   37,
#   35,
#   99,
#   93,
#   98,
#   7,
#   28,
#   95,
#   57],
#  'Speed': [58,
#   36,
#   64,
#   68,
#   68,
#   15,
#   63,
#   33,
#   73,
#   66,
#   84,
#   55,
#   95,
#   14,
#   78,
#   8,
#   4,
#   63,
#   70,
#   91,
#   2,
#   71,
#   18,
#   54,
#   54,
#   44,
#   83,
#   25,
#   31,
#   48,
#   54,
#   43,
#   10,
#   27,
#   67,
#   64,
#   64,
#   86,
#   83,
#   88,
#   28,
#   90,
#   81,
#   0,
#   68,
#   7,
#   68,
#   99,
#   74,
#   29,
#   79,
#   96,
#   84,
#   80,
#   66,
#   100,
#   38,
#   8,
#   0,
#   29,
#   46,
#   43,
#   42,
#   31,
#   83,
#   62,
#   70,
#   3,
#   55,
#   85,
#   48,
#   14,
#   91,
#   78,
#   72,
#   98,
#   95,
#   27,
#   39,
#   57,
#   81,
#   59,
#   30,
#   26,
#   0,
#   70,
#   91,
#   55,
#   91,
#   95,
#   4,
#   15,
#   44,
#   64,
#   3,
#   35,
#   96,
#   48,
#   89,
#   39]}

# %%
df1=pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    47.030000   52.910000   51.440000   54.200000
# std     28.405952   29.791564   29.652642   29.280945
# min      0.000000    0.000000    0.000000    0.000000
# 25%     21.000000   27.000000   26.750000   30.750000
# 50%     46.500000   57.000000   49.000000   58.500000
# 75%     66.250000   78.000000   77.500000   79.250000
# max    100.000000   99.000000   99.000000  100.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    58      88
# 1    65       8
# 2    20      55
# 3    78      86
# 4     0      46
# ..  ...     ...
# 95   66      89
# 96   62      44
# 97   57       1
# 98   60      78
# 99   85      65
#
# [100 rows x 2 columns]

# %%
df1.loc[0:3,['Age','Height']]
# Out:
#    Age  Height
# 0   58      88
# 1   65       8
# 2   20      55
# 3   78      86

# %%
df2=df1[['Age','Height']]

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    58      88      77     58
# 1    65       8      87     36
# 2    20      55      74     64
# 3    78      86      75     68
# 4     0      46      66     68
# ..  ...     ...     ...    ...
# 95   66      89      98     35
# 96   62      44       7     96
# 97   57       1      28     48
# 98   60      78      95     89
# 99   85      65      57     39
#
# [100 rows x 4 columns]

# %%
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0    58      88      77     58
# 2    20      55      74     64
# 4     0      46      66     68
# 6    63      56      52     63
# 8    87      97      61     73
# 10   10      27      61     84
# 12   62      28      82     95
# 14   66      94      48     78
# 16   14      36       8      4
# 18   22      58      62     70
# 20   67       9      96      2
# 22   17      84      25     18
# 24   16      14      20     54
# 26   98      71      17     83
# 28   67      16      67     31
# 30   29      27      50     54
# 32   87      74       5     10
# 34   54      50      80     67
# 36   13      85      94     64
# 38   39      44      90     83
# 40   62      62      74     28
# 42   52      60      43     81
# 44   90      78      40     68
# 46   59      97      51     68
# 48    9      44      25     74
# 50   73       5      83     79
# 52   91      19      30     84
# 54   42      87       5     66
# 56   46      33      55     38
# 58   52      59      23      0
# 60    7      58      42     46
# 62   67       3      65     42
# 64   95      66      57     83
# 66   27      96      15     70
# 68   21      99      16     55
# 70   34      80      95     48
# 72   91      27      85     91
# 74   61      22      94     72
# 76   81      46      31     95
# 78   57      65      58     39
# 80   21      52      19     81
# 82   77      13      63     30
# 84   21      23      86      0
# 86   66       0      68     91
# 88   99      17       3     91
# 90   45      65      86      4
# 92    9       9      35     44
# 94   32      57      93      3
# 96   62      44       7     96
# 98   60      78      95     89

# %%
df1[0::2].describe()
# Out:
#              Age     Height     Weight      Speed
# count  50.000000  50.000000  50.000000  50.000000
# mean   49.960000  50.460000  53.540000  57.580000
# std    28.310206  28.922282  29.189186  29.126809
# min     0.000000   0.000000   3.000000   0.000000
# 25%    21.250000  27.000000  26.250000  39.750000
# 50%    55.500000  53.500000  57.500000  66.500000
# 75%    67.000000  73.250000  79.250000  81.000000
# max    99.000000  99.000000  96.000000  96.000000

# %%
filter1=df1['Weight']>50

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    58      88      77     58
# 1    65       8      87     36
# 2    20      55      74     64
# 3    78      86      75     68
# 4     0      46      66     68
# 6    63      56      52     63
# 8    87      97      61     73
# 10   10      27      61     84
# 12   62      28      82     95
# 15   63      58      86      8
# 18   22      58      62     70
# 20   67       9      96      2
# 23    7      65      61     54
# 28   67      16      67     31
# 33   31      72      90     27
# 34   54      50      80     67
# 36   13      85      94     64
# 38   39      44      90     83
# 39   18      27      79     88
# 40   62      62      74     28
# 41   64      49      74     90
# 43   19      57      90      0
# 45   47      63      73      7
# 46   59      97      51     68
# 50   73       5      83     79
# 55   30      59      99    100
# 56   46      33      55     38
# 57   41      86      88      8
# 61   42       1      62     43
# 62   67       3      65     42
# 64   95      66      57     83
# 67    4      86      83      3
# 70   34      80      95     48
# 72   91      27      85     91
# 74   61      22      94     72
# 75   49      27      70     98
# 78   57      65      58     39
# 82   77      13      63     30
# 83   35      94      97     26
# 84   21      23      86      0
# 85   34      19      71     70
# 86   66       0      68     91
# 89   30      76      98     95
# 90   45      65      86      4
# 93    5      67      99     64
# 94   32      57      93      3
# 95   66      89      98     35
# 98   60      78      95     89
# 99   85      65      57     39

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    58      88      77     58
# 1    65       8      87     36
# 2    20      55      74     64
# 3    78      86      75     68
# 4     0      46      66     68
# 6    63      56      52     63
# 8    87      97      61     73
# 10   10      27      61     84
# 12   62      28      82     95
# 15   63      58      86      8
# 18   22      58      62     70
# 20   67       9      96      2
# 23    7      65      61     54
# 28   67      16      67     31
# 33   31      72      90     27
# 34   54      50      80     67
# 36   13      85      94     64
# 38   39      44      90     83
# 39   18      27      79     88
# 40   62      62      74     28
# 41   64      49      74     90
# 43   19      57      90      0
# 45   47      63      73      7
# 46   59      97      51     68
# 50   73       5      83     79
# 55   30      59      99    100
# 56   46      33      55     38
# 57   41      86      88      8
# 61   42       1      62     43
# 62   67       3      65     42
# 64   95      66      57     83
# 67    4      86      83      3
# 70   34      80      95     48
# 72   91      27      85     91
# 74   61      22      94     72
# 75   49      27      70     98
# 78   57      65      58     39
# 82   77      13      63     30
# 83   35      94      97     26
# 84   21      23      86      0
# 85   34      19      71     70
# 86   66       0      68     91
# 89   30      76      98     95
# 90   45      65      86      4
# 93    5      67      99     64
# 94   32      57      93      3
# 95   66      89      98     35
# 98   60      78      95     89
# 99   85      65      57     39

# %%
filter2=df1['Age']>50

# %%
df1[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    58      88      77     58
# 1    65       8      87     36
# 3    78      86      75     68
# 6    63      56      52     63
# 8    87      97      61     73
# 12   62      28      82     95
# 15   63      58      86      8
# 20   67       9      96      2
# 28   67      16      67     31
# 34   54      50      80     67
# 40   62      62      74     28
# 41   64      49      74     90
# 46   59      97      51     68
# 50   73       5      83     79
# 62   67       3      65     42
# 64   95      66      57     83
# 72   91      27      85     91
# 74   61      22      94     72
# 78   57      65      58     39
# 82   77      13      63     30
# 86   66       0      68     91
# 95   66      89      98     35
# 98   60      78      95     89
# 99   85      65      57     39
