# %% [markdown]
# <a href="https://colab.research.google.com/github/prasannaNRI-degree/Python-Mini-Project/blob/main/Day%202%20of%20Data%20Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
datasetpath='//content/drive/MyDrive/Document from Prasanna'

# %%
import pandas as pd

# %%
datasetpath='//content/drive/MyDrive/Document from Prasanna'

# %%
df=pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
ScoreAboveZero=df['Score']>'0-0'

# %%
df[ScoreAboveZero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# 5        0.9           NaN  Gareth Southgate            Harry Kane  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# 5                               NaN                             NaN
# ..                              ...                             ...
# 959                             NaN                             NaN
# 960                             NaN                             NaN
# 961                             NaN                             NaN
# 962                             NaN                             NaN
# 963                             NaN                             NaN
#
#      home_red_card         away_red_card   home_yellow_red_card  \
# 1              NaN                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN  Walid Cheddira · 90+3
# 5              NaN                   NaN                    NaN
# ..             ...                   ...                    ...
# 959            NaN                   NaN                    NaN
# 960            NaN                   NaN                    NaN
# 961            NaN  Plácido Galindo · 70                    NaN
# 962            NaN                   NaN                    NaN
# 963            NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# 5                    NaN                   ['90&rsquor;|1:2|Harry Maguire']
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [929 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
ScoreByBrazil=df['home_team']=='Brazil'

# %%
df[ScoreAboveZero & ScoreByBrazil]
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager               home_captain  \
# 11       0.5           NaN                 Tite               Thiago Silva
# 34       0.3           NaN                 Tite               Thiago Silva
# 51       0.2           NaN                 Tite               Thiago Silva
# 71       0.5           NaN                 Tite                    Miranda
# 74       0.7           NaN                 Tite               Thiago Silva
# ..       ...           ...                  ...                        ...
# 911      NaN           NaN       Ademar Pimenta                   Leônidas
# 915      NaN           NaN       Ademar Pimenta                   Leônidas
# 917      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 926      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 951      NaN           NaN  Pindaro De Carvalho                  Preguinho
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11   ...                             NaN                             NaN
# 34   ...                             NaN                             NaN
# 51   ...                             NaN                             NaN
# 71   ...                             NaN                             NaN
# 74   ...                             NaN                             NaN
# ..   ...                             ...                             ...
# 911  ...                             NaN                             NaN
# 915  ...                             NaN                             NaN
# 917  ...                             NaN                             NaN
# 926  ...                             NaN                             NaN
# 951  ...                             NaN                             NaN
#
#                               home_red_card  away_red_card  \
# 11                                      NaN            NaN
# 34                                      NaN            NaN
# 51                                      NaN            NaN
# 71                                      NaN            NaN
# 74                                      NaN            NaN
# ..                                      ...            ...
# 911                                     NaN            NaN
# 915                                     NaN            NaN
# 917  Zezé Procópio · 14|Arthur Machado · 89  Jan Říha · 89
# 926                                     NaN            NaN
# 951                                     NaN            NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 11                   NaN                  NaN
# 34                   NaN                  NaN
# 51                   NaN                  NaN
# 71                   NaN                  NaN
# 74                   NaN                  NaN
# ..                   ...                  ...
# 911                  NaN                  NaN
# 915                  NaN                  NaN
# 917                  NaN                  NaN
# 926                  NaN                  NaN
# 951                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# 51                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# 51   ['7&rsquor;|0:0|Strahinja Pavlović', '49&rsquo...
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# 51   ['75&rsquor;|2:0|Fred|for Lucas Paquetá', '76&...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# 51   ['57&rsquor;|0:0|Ivan Ilić|for Nemanja Gudelj'...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
# [81 rows x 44 columns]

# %%
df[ScoreAboveZero & ScoreByBrazil].sort_values
# Out:
# <bound method DataFrame.sort_values of     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager               home_captain  \
# 11       0.5           NaN                 Tite               Thiago Silva
# 34       0.3           NaN                 Tite               Thiago Silva
# 51       0.2           NaN                 Tite               Thiago Silva
# 71       0.5           NaN                 Tite                    Miranda
# 74       0.7           NaN                 Tite               Thiago Silva
# ..       ...           ...                  ...                        ...
# 911      NaN           NaN       Ademar Pimenta                   Leônidas
# 915      NaN           NaN       Ademar Pimenta                   Leônidas
# 917      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 926      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 951      NaN           NaN  Pindaro De Carvalho                  Preguinho
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11   ...                             NaN                             NaN
# 34   ...                             NaN                             NaN
# 51   ...                             NaN                             NaN
# 71   ...                             NaN                             NaN
# 74   ...                             NaN                             NaN
# ..   ...                             ...                             ...
# 911  ...                             NaN                             NaN
# 915  ...                             NaN                             NaN
# 917  ...                             NaN                             NaN
# 926  ...                             NaN                             NaN
# 951  ...                             NaN                             NaN
#
#                               home_red_card  away_red_card  \
# 11                                      NaN            NaN
# 34                                      NaN            NaN
# 51                                      NaN            NaN
# 71                                      NaN            NaN
# 74                                      NaN            NaN
# ..                                      ...            ...
# 911                                     NaN            NaN
# 915                                     NaN            NaN
# 917  Zezé Procópio · 14|Arthur Machado · 89  Jan Říha · 89
# 926                                     NaN            NaN
# 951                                     NaN            NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 11                   NaN                  NaN
# 34                   NaN                  NaN
# 51                   NaN                  NaN
# 71                   NaN                  NaN
# 74                   NaN                  NaN
# ..                   ...                  ...
# 911                  NaN                  NaN
# 915                  NaN                  NaN
# 917                  NaN                  NaN
# 926                  NaN                  NaN
# 951                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# 51                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# 51   ['7&rsquor;|0:0|Strahinja Pavlović', '49&rsquo...
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# 51   ['75&rsquor;|2:0|Fred|for Lucas Paquetá', '76&...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# 51   ['57&rsquor;|0:0|Ivan Ilić|for Nemanja Gudelj'...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
# [81 rows x 44 columns]>

# %%
brazildf=df[ScoreAboveZero & ScoreByBrazil].sort_values(by='home_score', ascending=True)

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 512 to 893
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
#  12  Attendance                       81 non-null     int64
#  13  Venue                            81 non-null     object
#  14  Officials                        64 non-null     object
#  15  Round                            81 non-null     object
#  16  Date                             81 non-null     object
#  17  Score                            81 non-null     object
#  18  Referee                          64 non-null     object
#  19  Notes                            3 non-null      object
#  20  Host                             81 non-null     object
#  21  Year                             81 non-null     int64
#  22  home_goal                        71 non-null     object
#  23  away_goal                        38 non-null     object
#  24  home_goal_long                   71 non-null     object
#  25  away_goal_long                   38 non-null     object
#  26  home_own_goal                    2 non-null      object
#  27  away_own_goal                    2 non-null      object
#  28  home_penalty_goal                8 non-null      object
#  29  away_penalty_goal                8 non-null      object
#  30  home_penalty_miss_long           0 non-null      object
#  31  away_penalty_miss_long           0 non-null      object
#  32  home_penalty_shootout_goal_long  0 non-null      object
#  33  away_penalty_shootout_goal_long  0 non-null      object
#  34  home_penalty_shootout_miss_long  0 non-null      object
#  35  away_penalty_shootout_miss_long  0 non-null      object
#  36  home_red_card                    4 non-null      object
#  37  away_red_card                    3 non-null      object
#  38  home_yellow_red_card             1 non-null      object
#  39  away_yellow_red_card             3 non-null      object
#  40  home_yellow_card_long            43 non-null     object
#  41  away_yellow_card_long            47 non-null     object
#  42  home_substitute_in_long          51 non-null     object
#  43  away_substitute_in_long          55 non-null     object
# dtypes: float64(4), int64(4), object(36)
# memory usage: 28.5+ KB

# %%
matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x='home_score',y='away_score',kind='scatter')
plt.xlabel('Home score')
plt.ylabel('Away score')
plt.legend('Takeaway score')
plt.title('Brazil Matches')
plt.show()

# %%
brazildf.plot(x='Year',y='home_score',kind='hexbin')
plt.xlabel('Year')
plt.ylabel('Home Score')
plt.legend('Takeaway')
plt.title('Brazil Matches')
plt.show()

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
def AnalyzeFrance():
    matchesplayed=df['home_team'].value_counts()['France']
    print(f'Total Number of matches played by France is :{matchesplayed}')

# %%
AnalyzeFrance()
# Out:
# Total Number of matches played by France is :38

# %%
def AnalyzeTowns():
  TownData =df['home_team'].value_counts()
  for _ in TownData.index:
    print(f'Total Number of matches played {_} is :{TownData[_]}')

# %%
AnalyzeTowns()
# Out:
# Total Number of matches played Brazil is :85
# Total Number of matches played Argentina is :59
# Total Number of matches played Italy is :57
# Total Number of matches played England is :40
# Total Number of matches played Germany is :40
# Total Number of matches played France is :38
# Total Number of matches played West Germany is :38
# Total Number of matches played Spain is :34
# Total Number of matches played Netherlands is :33
# Total Number of matches played Uruguay is :33
# Total Number of matches played Sweden is :30
# Total Number of matches played Belgium is :23
# Total Number of matches played Portugal is :21
# Total Number of matches played Poland is :20
# Total Number of matches played Soviet Union is :18
# Total Number of matches played Hungary is :18
# Total Number of matches played Mexico is :18
# Total Number of matches played Korea Republic is :18
# Total Number of matches played Switzerland is :16
# Total Number of matches played United States is :16
# Total Number of matches played Yugoslavia is :16
# Total Number of matches played Japan is :15
# Total Number of matches played Chile is :14
# Total Number of matches played Cameroon is :13
# Total Number of matches played Austria is :12
# Total Number of matches played Paraguay is :11
# Total Number of matches played Nigeria is :11
# Total Number of matches played Denmark is :10
# Total Number of matches played Czechoslovakia is :10
# Total Number of matches played Croatia is :10
# Total Number of matches played Scotland is :9
# Total Number of matches played Romania is :9
# Total Number of matches played Colombia is :8
# Total Number of matches played Morocco is :8
# Total Number of matches played Saudi Arabia is :8
# Total Number of matches played Australia is :8
# Total Number of matches played Costa Rica is :8
# Total Number of matches played Tunisia is :7
# Total Number of matches played Bulgaria is :7
# Total Number of matches played Peru is :6
# Total Number of matches played South Africa is :6
# Total Number of matches played Russia is :6
# Total Number of matches played Algeria is :6
# Total Number of matches played Ecuador is :5
# Total Number of matches played IR Iran is :5
# Total Number of matches played Ghana is :5
# Total Number of matches played Republic of Ireland is :5
# Total Number of matches played Honduras is :5
# Total Number of matches played Northern Ireland is :5
# Total Number of matches played Serbia is :4
# Total Number of matches played Greece is :4
# Total Number of matches played Senegal is :4
# Total Number of matches played Korea DPR is :3
# Total Number of matches played Germany DR is :3
# Total Number of matches played Slovenia is :3
# Total Number of matches played Côte d'Ivoire is :3
# Total Number of matches played Wales is :3
# Total Number of matches played Iraq is :2
# Total Number of matches played Zaire is :2
# Total Number of matches played Cuba is :2
# Total Number of matches played Canada is :2
# Total Number of matches played Qatar is :2
# Total Number of matches played Slovakia is :2
# Total Number of matches played Czech Republic is :2
# Total Number of matches played Togo is :2
# Total Number of matches played Türkiye is :2
# Total Number of matches played China PR is :1
# Total Number of matches played United Arab Emirates is :1
# Total Number of matches played Haiti is :1
# Total Number of matches played Panama is :1
# Total Number of matches played Iceland is :1
# Total Number of matches played Egypt is :1
# Total Number of matches played Ukraine is :1
# Total Number of matches played New Zealand is :1
# Total Number of matches played Norway is :1
# Total Number of matches played Bolivia is :1
# Total Number of matches played Serbia and Montenegro is :1
# Total Number of matches played Jamaica is :1
# Total Number of matches played FR Yugoslavia is :1
# Total Number of matches played Angola is :1
# Total Number of matches played Trinidad and Tobago is :1
# Total Number of matches played Bosnia and Herzegovina is :1

# %%
matplotlib inline

# %%
Town30=df['home_team'].value_counts(). values>30

# %%
Town30
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
townName=[]
Matchesplayed=[]
TownData=df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_]>30:
    townName.append(_)
    Matchesplayed.append(TownData[_])

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(Matchesplayed,townName)
plt.xlabel('TownName')
plt.ylabel('Matches played by Towns')
plt.show()

# %%
Above = df['home_team']

# %%
def matchesplayedByTown():
    townName=[]
    Matchesplayed=[]
    TownData=df['home_team'].value_counts()
    for _ in TownData.index:
     if TownData[_]>30:
      townName.append(_)
      Matchesplayed.append(TownData[_])
    plt.bar(Matchesplayed,townName)
    plt.xlabel('TownName')
    plt.ylabel('Matches played by Towns')
    plt.show()

# %%
matchesplayedByTown()

# %%
def MatchesplayedByTown2():
    Above30 = df['home_team'].value_counts()
    filteredData = Above30[Above30 > 30]
    filteredData.plot(kind='barh')

# %%
MatchesplayedByTown2()
